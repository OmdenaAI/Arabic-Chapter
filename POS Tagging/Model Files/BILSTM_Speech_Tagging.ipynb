# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import *
from keras.optimizers import Adam,SGD
from keras.models import Model
from keras.preprocessing.text import Tokenizer
from keras.callbacks import ModelCheckpoint, EarlyStopping, Callback, TensorBoard,ReduceLROnPlateau
from sklearn.metrics import recall_score, precision_score, classification_report, accuracy_score, confusion_matrix, f1_score
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix
import re
import gensim
import itertools
from nltk import ngrams
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## PreProcess Data

# %%
def process_csv(csv):
    df = pd.read_csv(csv)
    train_text ,train_tags = [] ,[]
    for i in tqdm(df['sentence_id'].unique()):
      train_text.append(df[df['sentence_id'] == i]['word'].tolist())
      train_tags.append(df[df['sentence_id'] == i]['tag'].tolist())
    return train_text,train_tags

# %%
train_text ,train_tags = process_csv('final_POS_data.csv')
# Out:
# 100%|██████████| 36891/36891 [01:57<00:00, 313.18it/s]

# %%
train_text[0],train_tags[0]
# Out:
# (['جاء',
#   'توقيع',
#   'اتفاقية',
#   'التعاون',
#   'العسكرى',
#   'بين',
#   'مصر',
#   'والسودان',
#   'الثلاثاء',
#   'الماضى',
#   'فى',
#   'الخرطوم',
#   'ليدشن',
#   'مرحلة',
#   'جديدة',
#   'فى',
#   'تطوير',
#   'العلاقات',
#   'الإستراتيجية',
#   'بين',
#   'البلدين',
#   'الشقيقين',
#   'فى',
#   'توقيت',
#   'بالغ',
#   'الأهمية',
#   ',',
#   'فالأوضاع',
#   'الإقليمية',
#   'والدولية',
#   'ي'],
#  ['Verb',
#   'Noun',
#   'Noun',
#   'Noun',
#   'Adjective',
#   'Noun',
#   'Proper Noun',
#   'Proper Noun',
#   'Noun',
#   'Adjective',
#   'Preposition',
#   'Proper Noun',
#   'Verb',
#   'Noun',
#   'Adjective',
#   'Preposition',
#   'Noun',
#   'Noun',
#   'Adjective',
#   'Noun',
#   'Noun',
#   'Adjective',
#   'Preposition',
#   'Noun',
#   'Adjective',
#   'Noun',
#   'Punctuation',
#   'Noun',
#   'Adjective',
#   'Adjective',
#   'Abbreviation'])

# %%
plt.style.use("ggplot")
plt.hist([len(s) for s in train_text], bins=50)
plt.show()

# %%
print('Max sentence length:',len(max(train_text, key=len)))
# Out:
# Max sentence length: 68

# %%
# Clean/Normalize Arabic Text
def clean_str(text):
    
    #remove tashkeel
    p_tashkeel = re.compile(r'[\u0617-\u061A\u064B-\u0652]')
    text = re.sub(p_tashkeel,"", text)
    
    #remove longation
    p_longation = re.compile(r'(.)\1+')
    subst = r"\1\1"
    text = re.sub(p_longation, subst, text)
    
    text = text.replace('وو', 'و')
    text = text.replace('يي', 'ي')
    text = text.replace('اا', 'ا')
    text = text.replace('أ', 'ا')
    text = text.replace('إ', 'ا')
    text = text.replace('آ', 'ا')
    text = text.replace('ى', 'ي')

    return text.split()

# %%
for i in range(len(train_text)):
  train_text[i] = clean_str(' '.join(train_text[i]))

# %%
embedding_dim = 300
MAX_SEQUENCE_LENGTH = 50
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# %%
word_tokenizer = Tokenizer(oov_token = oov_tok)                    
word_tokenizer.fit_on_texts(train_text)  
VOCABULARY_SIZE = len(word_tokenizer.word_index) + 1                  
X_encoded_train = word_tokenizer.texts_to_sequences(train_text)

# %%
tag_tokenizer = Tokenizer()
tag_tokenizer.fit_on_texts(train_tags)
Y_encoded_train = tag_tokenizer.texts_to_sequences(train_tags)

# %%
X_train = pad_sequences(X_encoded_train, maxlen=MAX_SEQUENCE_LENGTH, padding=padding_type, truncating=trunc_type)
Y_train = pad_sequences(Y_encoded_train, maxlen=MAX_SEQUENCE_LENGTH, padding=padding_type, truncating=trunc_type)

# %%
Y_train.shape
# Out:
# (36891, 50)

# %%
Y_train = to_categorical(Y_train)

# %%
Y_train.shape
# Out:
# (36891, 50, 35)

# %%
X_train, X_valid , Y_train, Y_valid = train_test_split(X_train, Y_train, test_size = 0.20, random_state = 41)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=0.15, random_state=41)

# %%
# print number of samples in each set
print("TRAINING DATA")
print('Shape of input sequences: {}'.format(X_train.shape))
print('Shape of output sequences: {}'.format(Y_train.shape))
print("-"*50)
print("VALIDATION DATA")
print('Shape of input sequences: {}'.format(X_valid.shape))
print('Shape of output sequences: {}'.format(Y_valid.shape))
print("-"*50)
print("TESTING DATA")
print('Shape of input sequences: {}'.format(X_test.shape))
print('Shape of output sequences: {}'.format(Y_test.shape))
# Out:
# TRAINING DATA
# Shape of input sequences: (25085, 50)
# Shape of output sequences: (25085, 50, 35)
# --------------------------------------------------
# VALIDATION DATA
# Shape of input sequences: (7379, 50)
# Shape of output sequences: (7379, 50, 35)
# --------------------------------------------------
# TESTING DATA
# Shape of input sequences: (4427, 50)
# Shape of output sequences: (4427, 50, 35)

# %%
NUM_CLASSES = Y_train.shape[2]
NUM_CLASSES
# Out:
# 35

# %% [markdown]
# ## Embedding Matrix

# %%
# !wget https://bakrianoo.ewr1.vultrobjects.com/aravec/full_grams_cbow_300_twitter.zip
# !unzip full_grams_cbow_300_twitter.zip
# Out:
# --2021-06-09 21:16:37--  https://bakrianoo.ewr1.vultrobjects.com/aravec/full_grams_cbow_300_twitter.zip
# Resolving bakrianoo.ewr1.vultrobjects.com (bakrianoo.ewr1.vultrobjects.com)... 108.61.0.122, 2001:19f0:0:22::100
# Connecting to bakrianoo.ewr1.vultrobjects.com (bakrianoo.ewr1.vultrobjects.com)|108.61.0.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3325529808 (3.1G) [application/zip]
# Saving to: ‘full_grams_cbow_300_twitter.zip’
#
# full_grams_cbow_300 100%[===================>]   3.10G  41.3MB/s    in 81s
#
# 2021-06-09 21:17:58 (39.1 MB/s) - ‘full_grams_cbow_300_twitter.zip’ saved [3325529808/3325529808]
#
# Archive:  full_grams_cbow_300_twitter.zip
#   inflating: full_grams_cbow_300_twitter.mdl
#   inflating: full_grams_cbow_300_twitter.mdl.trainables.syn1neg.npy
#   inflating: full_grams_cbow_300_twitter.mdl.wv.vectors.npy

# %%
embedding_model = gensim.models.Word2Vec.load('full_grams_cbow_300_twitter.mdl')
embeddings = {}
for word,vector in zip(embedding_model.wv.vocab,embedding_model.wv.vectors):
    coefs = np.array(vector, dtype='float32')
    embeddings[word] = coefs
embeddings_weights = np.zeros((VOCABULARY_SIZE, embedding_dim))
for word, i in word_tokenizer.word_index.items():
    embedding_vector = embeddings.get(word)
    if embedding_vector is not None:
        embeddings_weights[i] = embedding_vector

# %% [markdown]
# ## Create Model

# %%
model = Sequential()
model.add(InputLayer((MAX_SEQUENCE_LENGTH)))
model.add(Embedding(input_dim = VOCABULARY_SIZE,
                             output_dim    = embedding_dim,
                             input_length  = MAX_SEQUENCE_LENGTH,
                             weights = [embeddings_weights],
                             trainable     = True
))
model.add(Bidirectional(LSTM(256, return_sequences=True)))
model.add(Bidirectional(LSTM(256, return_sequences=True)))
model.add(Bidirectional(LSTM(256, return_sequences=True)))
model.add(Bidirectional(LSTM(256, return_sequences=True)))

model.add(TimeDistributed(Dense(NUM_CLASSES, activation='softmax')))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 50, 300)           21471300
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 50, 512)           1140736
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 50, 512)           1574912
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 50, 512)           1574912
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 50, 512)           1574912
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 50, 35)            17955
# =================================================================
# Total params: 27,354,727
# Trainable params: 27,354,727
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
checkpoint = ModelCheckpoint('Bi_LSTM_checkpoint.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
reducelr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=6, verbose=1, mode='min' , min_lr=0.00001)

# %%
result = model.fit(X_train, Y_train, validation_data= (X_valid, Y_valid), epochs = 50, batch_size= 128, shuffle = True,callbacks=[checkpoint,reducelr])
# Out:
# Epoch 1/50
# 196/196 [==============================] - 90s 295ms/step - loss: 1.0997 - accuracy: 0.7042 - val_loss: 0.2189 - val_accuracy: 0.9361
#
# Epoch 00001: val_accuracy improved from -inf to 0.93606, saving model to Bi_LSTM_checkpoint.h5
# Epoch 2/50
# 196/196 [==============================] - 55s 282ms/step - loss: 0.1615 - accuracy: 0.9537 - val_loss: 0.1028 - val_accuracy: 0.9690
#
# Epoch 00002: val_accuracy improved from 0.93606 to 0.96903, saving model to Bi_LSTM_checkpoint.h5
# Epoch 3/50
# 196/196 [==============================] - 55s 280ms/step - loss: 0.0603 - accuracy: 0.9831 - val_loss: 0.0847 - val_accuracy: 0.9749
#
# Epoch 00003: val_accuracy improved from 0.96903 to 0.97493, saving model to Bi_LSTM_checkpoint.h5
# Epoch 4/50
# 196/196 [==============================] - 55s 281ms/step - loss: 0.0298 - accuracy: 0.9918 - val_loss: 0.0857 - val_accuracy: 0.9763
#
# Epoch 00004: val_accuracy improved from 0.97493 to 0.97625, saving model to Bi_LSTM_checkpoint.h5
# Epoch 5/50
# 196/196 [==============================] - 56s 287ms/step - loss: 0.0179 - accuracy: 0.9951 - val_loss: 0.0865 - val_accuracy: 0.9781
#
# Epoch 00005: val_accuracy improved from 0.97625 to 0.97807, saving model to Bi_LSTM_checkpoint.h5
# Epoch 6/50
# 196/196 [==============================] - 56s 288ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.0894 - val_accuracy: 0.9779
#
# Epoch 00006: val_accuracy did not improve from 0.97807
# Epoch 7/50
# 196/196 [==============================] - 57s 289ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.0970 - val_accuracy: 0.9782
#
# Epoch 00007: val_accuracy improved from 0.97807 to 0.97819, saving model to Bi_LSTM_checkpoint.h5
# Epoch 8/50
# 196/196 [==============================] - 56s 287ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.1043 - val_accuracy: 0.9776
#
# Epoch 00008: val_accuracy did not improve from 0.97819
# Epoch 9/50
# 196/196 [==============================] - 56s 286ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.1073 - val_accuracy: 0.9783
#
# Epoch 00009: val_accuracy improved from 0.97819 to 0.97829, saving model to Bi_LSTM_checkpoint.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 10/50
# 196/196 [==============================] - 56s 288ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.1096 - val_accuracy: 0.9782
#
# Epoch 00010: val_accuracy did not improve from 0.97829
# Epoch 11/50
# 196/196 [==============================] - 56s 287ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1126 - val_accuracy: 0.9787
#
# Epoch 00011: val_accuracy improved from 0.97829 to 0.97870, saving model to Bi_LSTM_checkpoint.h5
# Epoch 12/50
# 196/196 [==============================] - 56s 287ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1155 - val_accuracy: 0.9788
#
# Epoch 00012: val_accuracy improved from 0.97870 to 0.97883, saving model to Bi_LSTM_checkpoint.h5
# Epoch 13/50
# 196/196 [==============================] - 56s 287ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1187 - val_accuracy: 0.9788
#
# Epoch 00013: val_accuracy improved from 0.97883 to 0.97883, saving model to Bi_LSTM_checkpoint.h5
# Epoch 14/50
# 196/196 [==============================] - 56s 287ms/step - loss: 9.1874e-04 - accuracy: 0.9998 - val_loss: 0.1218 - val_accuracy: 0.9788
#
# Epoch 00014: val_accuracy improved from 0.97883 to 0.97885, saving model to Bi_LSTM_checkpoint.h5
# Epoch 15/50
# 196/196 [==============================] - 56s 287ms/step - loss: 8.4008e-04 - accuracy: 0.9998 - val_loss: 0.1231 - val_accuracy: 0.9787
#
# Epoch 00015: val_accuracy did not improve from 0.97885
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 16/50
# 196/196 [==============================] - 57s 293ms/step - loss: 5.8905e-04 - accuracy: 0.9999 - val_loss: 0.1228 - val_accuracy: 0.9791
#
# Epoch 00016: val_accuracy improved from 0.97885 to 0.97914, saving model to Bi_LSTM_checkpoint.h5
# Epoch 17/50
# 196/196 [==============================] - 57s 292ms/step - loss: 3.8782e-04 - accuracy: 0.9999 - val_loss: 0.1250 - val_accuracy: 0.9791
#
# Epoch 00017: val_accuracy did not improve from 0.97914
# Epoch 18/50
# 196/196 [==============================] - 57s 289ms/step - loss: 2.9231e-04 - accuracy: 0.9999 - val_loss: 0.1290 - val_accuracy: 0.9788
#
# Epoch 00018: val_accuracy did not improve from 0.97914
# Epoch 19/50
# 196/196 [==============================] - 57s 289ms/step - loss: 2.5915e-04 - accuracy: 0.9999 - val_loss: 0.1291 - val_accuracy: 0.9788
#
# Epoch 00019: val_accuracy did not improve from 0.97914
# Epoch 20/50
# 196/196 [==============================] - 56s 288ms/step - loss: 2.4573e-04 - accuracy: 0.9999 - val_loss: 0.1279 - val_accuracy: 0.9787
#
# Epoch 00020: val_accuracy did not improve from 0.97914
# Epoch 21/50
# 196/196 [==============================] - 57s 289ms/step - loss: 3.0716e-04 - accuracy: 0.9999 - val_loss: 0.1320 - val_accuracy: 0.9788
#
# Epoch 00021: val_accuracy did not improve from 0.97914
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 22/50
# 196/196 [==============================] - 57s 288ms/step - loss: 2.0170e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9790
#
# Epoch 00022: val_accuracy did not improve from 0.97914
# Epoch 23/50
# 196/196 [==============================] - 57s 292ms/step - loss: 1.8609e-04 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9790
#
# Epoch 00023: val_accuracy did not improve from 0.97914
# Epoch 24/50
# 196/196 [==============================] - 57s 291ms/step - loss: 1.4937e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9790
#
# Epoch 00024: val_accuracy did not improve from 0.97914
# Epoch 25/50
# 196/196 [==============================] - 57s 289ms/step - loss: 1.2692e-04 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9791
#
# Epoch 00025: val_accuracy did not improve from 0.97914
# Epoch 26/50
# 196/196 [==============================] - 57s 291ms/step - loss: 1.6330e-04 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9790
#
# Epoch 00026: val_accuracy did not improve from 0.97914
# Epoch 27/50
# 196/196 [==============================] - 57s 290ms/step - loss: 1.3090e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9788
#
# Epoch 00027: val_accuracy did not improve from 0.97914
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 28/50
# 196/196 [==============================] - 57s 289ms/step - loss: 1.6849e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9789
#
# Epoch 00028: val_accuracy did not improve from 0.97914
# Epoch 29/50
# 196/196 [==============================] - 57s 290ms/step - loss: 1.8773e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9789
#
# Epoch 00029: val_accuracy did not improve from 0.97914
# Epoch 30/50
# 196/196 [==============================] - 57s 290ms/step - loss: 9.4172e-05 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9789
#
# Epoch 00030: val_accuracy did not improve from 0.97914
# Epoch 31/50
# 196/196 [==============================] - 57s 290ms/step - loss: 1.2154e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9789
#
# Epoch 00031: val_accuracy did not improve from 0.97914
# Epoch 32/50
# 196/196 [==============================] - 57s 291ms/step - loss: 1.4838e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9789
#
# Epoch 00032: val_accuracy did not improve from 0.97914
# Epoch 33/50
# 196/196 [==============================] - 57s 291ms/step - loss: 1.2197e-04 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9789
#
# Epoch 00033: val_accuracy did not improve from 0.97914
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 34/50
# 196/196 [==============================] - 57s 291ms/step - loss: 8.5629e-05 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9789
#
# Epoch 00034: val_accuracy did not improve from 0.97914
# Epoch 35/50
# 196/196 [==============================] - 56s 286ms/step - loss: 1.0941e-04 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9790
#
# Epoch 00035: val_accuracy did not improve from 0.97914
# Epoch 36/50
# 196/196 [==============================] - 57s 292ms/step - loss: 9.3638e-05 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9790
#
# Epoch 00036: val_accuracy did not improve from 0.97914
# Epoch 37/50
# 196/196 [==============================] - 57s 292ms/step - loss: 8.5121e-05 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9789
#
# Epoch 00037: val_accuracy did not improve from 0.97914
# Epoch 38/50
# 196/196 [==============================] - 57s 289ms/step - loss: 8.5300e-05 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9789
#
# Epoch 00038: val_accuracy did not improve from 0.97914
# Epoch 39/50
# 196/196 [==============================] - 57s 290ms/step - loss: 1.1285e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9790
#
# Epoch 00039: val_accuracy did not improve from 0.97914
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 40/50
# 196/196 [==============================] - 57s 290ms/step - loss: 6.2754e-05 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9790
#
# Epoch 00040: val_accuracy did not improve from 0.97914
# Epoch 41/50
# 196/196 [==============================] - 57s 289ms/step - loss: 7.1945e-05 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9790
#
# Epoch 00041: val_accuracy did not improve from 0.97914
# Epoch 42/50
# 196/196 [==============================] - 57s 291ms/step - loss: 8.6314e-05 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9790
#
# Epoch 00042: val_accuracy did not improve from 0.97914
# Epoch 43/50
# 196/196 [==============================] - 57s 290ms/step - loss: 9.5349e-05 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9789
#
# Epoch 00043: val_accuracy did not improve from 0.97914
# Epoch 44/50
# 196/196 [==============================] - 57s 291ms/step - loss: 6.7538e-05 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9789
#
# Epoch 00044: val_accuracy did not improve from 0.97914
# Epoch 45/50
# 196/196 [==============================] - 57s 291ms/step - loss: 8.9195e-05 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9789
#
# Epoch 00045: val_accuracy did not improve from 0.97914
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 46/50
# 196/196 [==============================] - 57s 289ms/step - loss: 8.3689e-05 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9789
#
# Epoch 00046: val_accuracy did not improve from 0.97914
# Epoch 47/50
# 196/196 [==============================] - 57s 290ms/step - loss: 7.1043e-05 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9789
#
# Epoch 00047: val_accuracy did not improve from 0.97914
# Epoch 48/50
# 196/196 [==============================] - 57s 290ms/step - loss: 5.4703e-05 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9789
#
# Epoch 00048: val_accuracy did not improve from 0.97914
# Epoch 49/50
# 196/196 [==============================] - 56s 288ms/step - loss: 8.5556e-05 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9790
#
# Epoch 00049: val_accuracy did not improve from 0.97914
# Epoch 50/50
# 196/196 [==============================] - 56s 288ms/step - loss: 7.5772e-05 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9789
#
# Epoch 00050: val_accuracy did not improve from 0.97914

# %% [markdown]
# ## Evaluate Model

# %%
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','val'],loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','val'],loc='upper right')
plt.show()

# %%
model.load_weights('Bi_LSTM_checkpoint.h5')

# %%
loss, accuracy = model.evaluate(X_test, Y_test, verbose = 1)
print("Loss: {0},\nAccuracy: {1}".format(loss, accuracy))
# Out:
# 139/139 [==============================] - 2s 17ms/step - loss: 0.1204 - accuracy: 0.9795
# Loss: 0.12044034153223038,
# Accuracy: 0.9794849753379822

# %% [markdown]
# ## Predict

# %%
def classify(sentence):
  sentence = clean_str(sentence)
  seq = [word_tokenizer.texts_to_sequences(sentence)]
  pad_seq = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH, padding=padding_type, truncating=trunc_type)
  pad_seq = np.squeeze(pad_seq,axis=-1)
  pred = np.squeeze(model.predict(pad_seq).argmax(-1))
  output = [tag_tokenizer.index_word[tag] for tag in pred if tag != 0]
  return output

# %%
sentence = "جون يحب البيت الأزرق في نهاية الشارع"
output = classify(sentence)
word_tag = [(sentence.split()[i],output[i]) for i in range(len(sentence.split()))]
print(word_tag)
# Out:
# [('جون', 'proper noun'), ('يحب', 'verb'), ('البيت', 'noun'), ('الأزرق', 'noun'), ('في', 'preposition'), ('نهاية', 'noun'), ('الشارع', 'noun')]
